# %% [markdown]
# # **<center><font color=brown>Exploratory Data Analysis on Iris Dataset</font></center>**

# %% [markdown]
# # **<font color=purple>Importing the Dependencies</font>**

# %%
#importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder #library to handle categorical data
from sklearn.preprocessing import StandardScaler #library for feature scaling
from sklearn.preprocessing import MinMaxScaler 
import warnings #ignore warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **<font color=purple>Importing Dataset</font>**

# %%
#loading the titanic dataset from csv file to pandas dataframe
df=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/7. Dataset/iris.csv')

# %% [markdown]
# # **<font color=purple>Introductory Details About Data</font>**

# %% [markdown]
# ### <font color=green>Viewing the first few rows of the dataset</font>

# %%
#printing the first five rows of the dataframe
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ### <font color=green>Viewing the last few rows of the dataset</font>

# %%
#printing the last five rows of the dataframe
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %% [markdown]
# ### <font color=green>Viewing the dimensionality of the dataset</font>

# %%
#total number of rows and column in the dataset
df.shape
# Out:
# (150, 5)

# %% [markdown]
# ### **Observation**<br>- Dataset comprises 150 observation(rows) and 5 features(columns)<br>- Out of the 5, one is the target variable and rest 4 are input varibles.

# %% [markdown]
# ### <font color=green>Getting Concise summary of the dataset</font>

# %%
#columns and their corresponding datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ### **Observation**<br> - The data has float and object values

# %% [markdown]
# ### <font color=green>Getting descriptive statistics of the data<font>

# %%
#statistics summary
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # **<font color=purple>Handling Missing Data</font>**

# %%
#checking null values in dataset
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ### <font color=green>Visualizing the Missing values</font>

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# ### **Observation**<br>- We see all the column in dataset are free from Null values.

# %% [markdown]
# ### <font color=green>Check Non Numeric Column in the Dataset</font>

# %%
#checking datatypes of each column
df.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %% [markdown]
# ## **Observation**<br>- We see Out of 5 columns, 4 columns have Numeric value, while 1 column is Categorical type, so we encode the categorical value.

# %% [markdown]
# # **<font color=purple>Handling Categorical Data</font>**

# %%
#Converting all Categorical data into Numerical data
le=LabelEncoder() #create object of LabelEncoder class
df['species']=le.fit_transform(df['species'])
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %% [markdown]
# ### **Observation**<br>- We see all the columns of our dataset are free from Categorical datatype

# %% [markdown]
# # **<font color=purple>Feature Scaling</font>**

# %% [markdown]
# ## **<font color=purple>- Standarization- StandardScaling</font>**

# %%
#from sklearn.preprocessing import StandScaler
ss=StandardScaler()
df_new=ss.fit_transform(df_new)
print(df_new)
# Out:
# [[-1.22474487e+00 -9.00681170e-01  1.03205722e+00 -1.34127240e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -1.14301691e+00 -1.24957601e-01 -1.34127240e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -1.38535265e+00  3.37848329e-01 -1.39813811e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -1.50652052e+00  1.06445364e-01 -1.28440670e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -1.02184904e+00  1.26346019e+00 -1.34127240e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -5.37177559e-01  1.95766909e+00 -1.17067529e+00
#   -1.05003079e+00]
#  [-1.22474487e+00 -1.50652052e+00  8.00654259e-01 -1.34127240e+00
#   -1.18150376e+00]
#  [-1.22474487e+00 -1.02184904e+00  8.00654259e-01 -1.28440670e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -1.74885626e+00 -3.56360566e-01 -1.34127240e+00
#   -1.31297673e+00]
#  [-1.22474487e+00 -1.14301691e+00  1.06445364e-01 -1.28440670e+00
#   -1.44444970e+00]
#  [-1.22474487e+00 -5.37177559e-01  1.49486315e+00 -1.28440670e+00
#   -1.31297673e+00]
# ...

# %% [markdown]
# ## **<font color=purple>- Normalization - MinMaxScaling</font>**

# %%
#from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
df_new=mms.fit_transform(df_new)
print(df_new)
# Out:
# [[0.         0.22222222 0.625      0.06779661 0.04166667]
#  [0.         0.16666667 0.41666667 0.06779661 0.04166667]
#  [0.         0.11111111 0.5        0.05084746 0.04166667]
#  [0.         0.08333333 0.45833333 0.08474576 0.04166667]
#  [0.         0.19444444 0.66666667 0.06779661 0.04166667]
#  [0.         0.30555556 0.79166667 0.11864407 0.125     ]
#  [0.         0.08333333 0.58333333 0.06779661 0.08333333]
#  [0.         0.19444444 0.58333333 0.08474576 0.04166667]
#  [0.         0.02777778 0.375      0.06779661 0.04166667]
#  [0.         0.16666667 0.45833333 0.08474576 0.        ]
#  [0.         0.30555556 0.70833333 0.08474576 0.04166667]
#  [0.         0.13888889 0.58333333 0.10169492 0.04166667]
#  [0.         0.13888889 0.41666667 0.06779661 0.        ]
#  [0.         0.         0.41666667 0.01694915 0.        ]
#  [0.         0.41666667 0.83333333 0.03389831 0.04166667]
#  [0.         0.38888889 1.         0.08474576 0.125     ]
# ...
