# %% [markdown]
# # <font color=red><center><u>**Data Visualization on IPL Dataset**</u><center></font>

# %% [markdown]
# ## <font color=purple>Importing the Dependencies</font>

# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## <font color=purple>Importing Dataset</font>

# %%
ipl=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/7. Dataset/matches.csv')

# %%
#printing the first few rows of the dataframe
ipl.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
#printing the last few rows of the dataframe
ipl.tail()
# Out:
#         id    Season           city        date                  team1  \
# 751  11347  IPL-2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019    Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# ...

# %%
#total number of rows and column in the dataset
ipl.shape
# Out:
# (756, 18)

# %% [markdown]
# ## **Observation**<br>- Dataset comprises 756 rows and 18 column.<br>- Out of 18, one is target variable and rest 17 is input variable.

# %%
#columns and their corresponding datatypes
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# ## **Observation**<br>- The data has int, float and object values.

# %%
#statistics summary
ipl.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %%
#checking null values
ipl.isnull().sum()
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
#visualizing null values
plt.figure(figsize=(10,5))
sns.heatmap(ipl.isnull())
plt.show()

# %% [markdown]
# # <font color=purple>**List of IPL Season**</font>

# %%
ipl['Season'].unique()
# Out:
# array(['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011',
#        'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016',
#        'IPL-2018', 'IPL-2019'], dtype=object)

# %%
plt.figure(figsize=(18,15))
sns.countplot(data=ipl,
              x='Season',
              order = ipl['Season'].value_counts().index.sort_values(),
              palette='cividis'
              )
c=ipl['Season'].value_counts()
plt.yticks(c)
plt.xticks()
plt.title('List of IPL Season',fontsize=16)
plt.show()

# %% [markdown]
# ## **Onservation**<br>- We see that dataset contains data of matches played from season 2008-2019.

# %% [markdown]
# # <font color=purple>**Number of Match Played in each IPL Season**</font>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Season',
              data=ipl,
              order = ipl['Season'].value_counts().index.sort_values(),
              palette='cividis'
              )
plt.xlabel('Season',fontsize=12)
plt.ylabel('No: of matches',fontsize=12)
plt.title('Number of matches played in each IPL season',fontsize=16)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that Most number of matches were played in IPL-2013 Season

# %% [markdown]
# # <font color=purple>**Most IPL Matches played in a Venue**</font>

# %%
ipl.groupby(['venue','id']).count().droplevel(level=1).index.value_counts()
# Out:
# Eden Gardens                                            77
# Wankhede Stadium                                        73
# M Chinnaswamy Stadium                                   73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %%
plt.figure(figsize = (12,8))
sns.countplot(y = 'venue',
              data = ipl,
              order = ipl['venue'].value_counts().iloc[:10].index,
              palette='gist_heat')
plt.xlabel('No: of matches',fontsize=12)
plt.ylabel('Venue',fontsize=12)
plt.title('Number of matches played in each Stadium',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Number of matches played in each Stadium')

# %% [markdown]
# # <font color=purple>**Team has most winning matches**</font>

# %%
ipl['winner'].value_counts().sum()
# Out:
# 752

# %%
ipl['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
# Matches won by the Teams
plt.figure(figsize = (11,9))
sns.countplot(y = 'winner',
              data = ipl,
              order= ipl['winner'].value_counts().index,
              palette = 'copper' )
plt.xlabel('No: of Wins',fontsize=12)
plt.ylabel('Team',fontsize=12)
plt.title('Matches won by the Teams',fontsize=16)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that Mumbai Indians won most number of matches followed by Chennai Super Kings

# %% [markdown]
# # <font color='purple'> **Team has Most Toss Wins in IPL**</font>

# %%
plt.figure(figsize=(10,8))
sns.countplot(y='toss_winner',
              data=ipl,
              order=ipl['toss_winner'].value_counts().index,
              palette='copper')
plt.xlabel('Matches won by the Teams',fontsize=12)
plt.ylabel('Team',fontsize=12)
plt.title('Most of Toss Winning Team',fontsize=16)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that Mumbai Indians won most number of Tosses followed by Kolkata Knight Riders

# %% [markdown]
# # <font color=purple>**Toss Decision**</font>

# %%
plt.figure(figsize=(6,6))
sizes = ipl.toss_decision.value_counts()
labels = ipl.toss_decision.value_counts().index
plt.pie(sizes,colors = ['#ff9999','#66b3ff'],
         labels=labels,
         autopct='%1.1f%%',
         startangle=90,
         pctdistance=0.75,
         explode = (0.025,0.025))

#draw white circle
centre_circle = plt.Circle((0,0),0.60,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that In more than 61% of matches, teams chose to field after winning the toss.

# %% [markdown]
# # <font color=purple>**Toss Decision to field or bat in each IPL season**</font>

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Season',
              hue='toss_decision',
              data=ipl,
              order = ipl['Season'].value_counts().index.sort_values(),
              palette='deep')
plt.xlabel('Season',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.title('Decision to field or bat in each IPL season', fontsize=16)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We can see a trend that, decisions to field are more from IPL-2016 Season.

# %% [markdown]
# # <font color=purple>**Player of the Match**</font>

# %%
plt.figure(figsize=(15,7))
player_of_match=ipl['player_of_match'].value_counts()[:10]
sns.barplot(player_of_match.index,
            player_of_match.values,
            palette='cividis')

plt.title("Player of the Match",fontsize=15)
plt.xlabel('Player',fontsize=12)
plt.ylabel('Count',fontsize=12)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that Chris Gayle won most Man of the Match Awards

# %% [markdown]
# # <font color=purple>**Mumbai Indians Team Winning chance after choosing field.**</font>

# %%
mi=ipl[(ipl['toss_winner']=='Mumbai Indians')&(ipl['toss_decision']=='field')]
mi
# Out:
#         id    Season           city        date                        team1  \
# 6        7  IPL-2017         Mumbai  09-04-2017        Kolkata Knight Riders
# 9       10  IPL-2017         Mumbai  12-04-2017          Sunrisers Hyderabad
# 11      12  IPL-2017      Bangalore  14-04-2017  Royal Challengers Bangalore
# 15      16  IPL-2017         Mumbai  16-04-2017                Gujarat Lions
# 21      22  IPL-2017         Indore  20-04-2017              Kings XI Punjab
# 27      28  IPL-2017         Mumbai  24-04-2017       Rising Pune Supergiant
# 49      50  IPL-2017         Mumbai  11-05-2017              Kings XI Punjab
# 55      56  IPL-2017         Mumbai  16-05-2017       Rising Pune Supergiant
# 57      58  IPL-2017      Bangalore  19-05-2017        Kolkata Knight Riders
# 66      67  IPL-2008        Chennai  23-04-2008          Chennai Super Kings
# 68      69  IPL-2008     Chandigarh  25-04-2008              Kings XI Punjab
# ...

# %%
plt.figure(figsize=(10,8))
mi['winner'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Teams Winning Chances after choosing Field')
plt.xlabel('Teams',fontsize=12)
plt.ylabel('chances',fontsize=12)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that there are 57.41% of Chances to Win if Mumbai Indians Choose Field.

# %% [markdown]
# # <font color=purple>**Mumbai Indians Winning chance after choosing Bat.**</font>

# %%
mi=ipl[(ipl['toss_winner']=='Mumbai Indians')&(ipl['toss_decision']=='bat')]
mi
# Out:
#         id    Season            city        date           team1  \
# 46      47  IPL-2017       Hyderabad  08-05-2017  Mumbai Indians
# 58      59  IPL-2017       Hyderabad  21-05-2017  Mumbai Indians
# 62      63  IPL-2008          Mumbai  20-04-2008  Mumbai Indians
# 131    132  IPL-2009  Port Elizabeth  27-04-2009  Mumbai Indians
# 137    138  IPL-2009     East London  01-05-2009  Mumbai Indians
# 142    143  IPL-2009    Johannesburg  03-05-2009  Mumbai Indians
# 149    150  IPL-2009     East London  08-05-2009  Mumbai Indians
# 152    153  IPL-2009  Port Elizabeth  10-05-2009  Mumbai Indians
# 161    162  IPL-2009  Port Elizabeth  16-05-2009  Mumbai Indians
# 175    176  IPL-2010          Mumbai  13-03-2010  Mumbai Indians
# 187    188  IPL-2010          Mumbai  20-03-2010  Mumbai Indians
# 206    207  IPL-2010          Mumbai  03-04-2010  Mumbai Indians
# 214    215  IPL-2010      Chandigarh  09-04-2010  Mumbai Indians
# ...

# %%
plt.figure(figsize=(10,8))
mi['winner'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Teams Winning Chances after choosing Bat')
plt.xlabel('Teams',fontsize=12)
plt.ylabel('chances',fontsize=12)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that there are 56.82% of Chances to Win if Mumbai Indians Choose Bat.

# %% [markdown]
# # <font color=purple>**Chennai Super Kings Winning chance after choosing field.**</font>

# %%
csk=ipl[(ipl['toss_winner']=='Chennai Super Kings')&(ipl['toss_decision']=='field')]
csk
# Out:
#         id    Season           city        date                        team1  \
# 86      87  IPL-2008          Delhi  08-05-2008             Delhi Daredevils
# 117    118  IPL-2009      Cape Town  18-04-2009               Mumbai Indians
# 189    190  IPL-2010        Chennai  21-03-2010              Kings XI Punjab
# 191    192  IPL-2010      Bangalore  23-03-2010  Royal Challengers Bangalore
# 227    228  IPL-2010     Dharamsala  18-04-2010              Kings XI Punjab
# 256    257  IPL-2011         Mumbai  22-04-2011               Mumbai Indians
# 303    304  IPL-2011         Mumbai  24-05-2011  Royal Challengers Bangalore
# 360    361  IPL-2012         Jaipur  10-05-2012             Rajasthan Royals
# 363    364  IPL-2012        Chennai  12-05-2012             Delhi Daredevils
# 367    368  IPL-2012        Kolkata  14-05-2012        Kolkata Knight Riders
# 390    391  IPL-2013     Chandigarh  10-04-2013              Kings XI Punjab
# ...

# %%
plt.figure(figsize=(10,8))
csk['winner'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Teams Winning Chances after choosing Bat')
plt.xlabel('Teams',fontsize=12)
plt.ylabel('chances',fontsize=12)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that there are 65.85% of Chances to Win if Chennai Super King Choose Field.

# %% [markdown]
# # <font color=purple>**Chennai Super Kings Winning chance after choosing Bat.**</font>

# %%
csk=ipl[(ipl['toss_winner']=='Chennai Super Kings')&(ipl['toss_decision']=='bat')]
csk
# Out:
#         id    Season            city        date                team1  \
# 60      61  IPL-2008      Chandigarh  19-04-2008  Chennai Super Kings
# 73      74  IPL-2008       Bangalore  28-04-2008  Chennai Super Kings
# 78      79  IPL-2008         Chennai  02-05-2008  Chennai Super Kings
# 82      83  IPL-2008          Jaipur  04-05-2008  Chennai Super Kings
# 121    122  IPL-2009  Port Elizabeth  20-04-2009  Chennai Super Kings
# 143    144  IPL-2009     East London  04-05-2009  Chennai Super Kings
# 148    149  IPL-2009       Centurion  07-05-2009  Chennai Super Kings
# 158    159  IPL-2009          Durban  14-05-2009  Chennai Super Kings
# 165    166  IPL-2009       Centurion  18-05-2009  Chennai Super Kings
# 168    169  IPL-2009          Durban  20-05-2009  Chennai Super Kings
# 181    182  IPL-2010         Kolkata  16-03-2010  Chennai Super Kings
# 205    206  IPL-2010         Chennai  03-04-2010  Chennai Super Kings
# ...

# %%
plt.figure(figsize=(10,8))
csk['winner'].value_counts().plot(kind='pie',autopct='%.2f%%')
plt.title('Teams Winning Chances after choosing Bat')
plt.xlabel('Teams',fontsize=12)
plt.ylabel('chances',fontsize=12)
plt.show()

# %% [markdown]
# ## **Observation**<br>- We see that there are 62.50% of Chances to Win if Chennai Super King Choose Bat.
